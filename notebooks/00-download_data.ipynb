# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv('../data/raw/data.csv', index=False)

# %%
dicionario = pd.DataFrame([        
    {
        "variavel": "survived",
        "descricao": "Indica se a pessoa sobreviveu ou não",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "pclass",
        "descricao": "Classe do passageiro no navio",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },{
        "variavel": "sex",
        "descricao": "Sexo do passageiro",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "age",
        "descricao": "Idade do passageiro",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "sibsp",
        "descricao": "Quantidade de irmãos ou cônjuges a bordo do navio",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "parch",
        "descricao": "Quantidade de pais ou filhos a bordo do navio",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "fare",
        "descricao": "Valor da tarifa do passageiro",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "embarked",
        "descricao": "Porto de embarcação do passageiro",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "class",
        "descricao": "Classe do passageiro no navio",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },{
        "variavel": "who",
        "descricao": "Indica se é homem, mulher ou criança",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "adult_male",
        "descricao": "Indica se é um homem adulto",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "deck",
        "descricao": "Convés em que o passageiro estava",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },{
        "variavel": "embark_town",
        "descricao": "Nome da cidade de embarque do passageiro",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "alive",
        "descricao": "Indica se a pessoa está viva ou não",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "alone",
        "descricao": "Indica se a pessoa viajou sem familiares ou cônjuges",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    }
])
dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#        variavel                                          descricao  \
# 0      survived               Indica se a pessoa sobreviveu ou não
# 1        pclass                      Classe do passageiro no navio
# 2           sex                                 Sexo do passageiro
# 3           age                                Idade do passageiro
# 4         sibsp  Quantidade de irmãos ou cônjuges a bordo do navio
# 5         parch      Quantidade de pais ou filhos a bordo do navio
# 6          fare                      Valor da tarifa do passageiro
# 7      embarked                  Porto de embarcação do passageiro
# 8         class                      Classe do passageiro no navio
# 9           who               Indica se é homem, mulher ou criança
# 10   adult_male                        Indica se é um homem adulto
# 11         deck                  Convés em que o passageiro estava
# 12  embark_town           Nome da cidade de embarque do passageiro
# ...
